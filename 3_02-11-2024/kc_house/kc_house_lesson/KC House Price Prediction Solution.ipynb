# %% [markdown]
# # <font color='purple'> King County House Price Prediction

# %% [markdown]
#  Bu projede King County WA da ev fiyatlarini regression ile tahmin eden modeli gelistirecegiz.
#
#  Data Kaggle projesinden alinmistir.
#
#  This dataset contains house sale prices for King County, which includes Seattle. It includes homes sold between May 2014 and May 2015.

# %% [markdown]
# Data Dictionary :
#
# id :a notation for a house
#
# date: Date house was sold
#
# price: Price is prediction target
#
# bedrooms: Number of Bedrooms/House
#
# bathrooms: Number of bathrooms/bedrooms
#
# sqft_living: square footage of the home
#
# sqft_lot: square footage of the lot
#
# floors :Total floors (levels) in house
#
# waterfront :House which has a view to a waterfront
#
# view: Has been viewed
#
# condition :How good the condition is Overall
#
# grade: overall grade given to the housing unit, based on King County grading system
#
# sqft_above :square footage of house apart from basement
#
# sqft_basement: square footage of the basement
#
# yr_built :Built Year
#
# yr_renovated :Year when house was renovated
#
# zipcode:zip code
#
# lat: Latitude coordinate
#
# long: Longitude coordinate
#
# sqft_living15 :Living room area in 2015(implies-- some renovations) This might or might not have affected the lotsize area
#
# sqft_lot15 :lotSize area in 2015(implies-- some renovations)

# %% [markdown]
# <img src='https://upload.wikimedia.org/wikipedia/commons/b/bc/Seattle_-_King_County_Courthouse_and_King_County_Administration_Building_01.jpg'>
# <a href='https://www.kaggle.com/code/shiv28/house-price-prediction-in-king-county-usa' target=_blank>Data Dosyasini burada bulabilirsiniz</a>

# %% [markdown]
# ## <font color='purple'>Requirement Packages

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns',55)
import datetime

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import RandomForestRegressor

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

from sklearn.linear_model import Ridge, Lasso,ElasticNet

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## <font color='purple'>Import Data

# %%
df=pd.read_csv('kc_house_data.csv')

# %%
#bulundugunuz klasordeki dosyalari listeler linux Shell komutu

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 7ECE-12C5
#
#  Directory of C:\Users\ckili\Downloads
#
# 11/03/2024  10:06 AM    <DIR>          .
# 11/02/2024  11:29 PM    <DIR>          ..
# 11/03/2024  09:52 AM    <DIR>          .ipynb_checkpoints
# 08/18/2024  04:52 PM           852,706 1137731.jpg
# 08/30/2024  10:14 PM            81,419 74870239-smart-school-school-management-system-license.pdf
# 09/03/2024  12:34 AM       146,993,887 a.zip
# 10/03/2024  09:56 PM           655,676 Adsiz tasarim (1).png
# 10/03/2024  10:39 PM         1,605,795 Adsiz tasarim (2).png
# 10/03/2024  09:52 PM           610,798 Adsiz tasarim.png
# 10/06/2024  12:17 PM       956,650,896 Anaconda3-2024.06-1-Windows-x86_64.exe
# 09/09/2024  08:38 PM            55,947 app (1).php
# 09/09/2024  08:39 PM                10 app (2).php
# 09/09/2024  08:40 PM                10 app (3).php
# 09/03/2024  08:37 PM             3,823 App.php
# 09/03/2024  08:13 PM        92,756,638 application.zip
# ...

# %%
# calisilan klasorun yolunu soyluyor

# %%
pwd
# Out:
# 'C:\\Users\\ckili\\Downloads'

# %% [markdown]
# ## <font color='purple'> EDA (Exploratory Data Analysis)

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 21608         1530      1131     3.0           0     0          3      8
# 21609         2310      5813     2.0           0     0          3      8
# 21610         1020      1350     2.0           0     0          3      7
# 21611         1600      2388     2.0           0     0          3      8
# 21612         1020      1076     2.0           0     0          3      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df['bedrooms'].mean()- 3*df['bedrooms'].std(),df['bedrooms'].mean()+ 3*df['bedrooms'].std() # outlier bulma
# Out:
# (0.58065612965482, 6.1610271165396)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.corr(numeric_only=True)
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap="crest")
# Out:
# <Axes: >

# %%
abs(df.corr(numeric_only=True)['price']).sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# bathrooms        0.525138
# view             0.397293
# sqft_basement    0.323816
# bedrooms         0.308350
# lat              0.307003
# waterfront       0.266369
# floors           0.256794
# yr_renovated     0.126434
# sqft_lot         0.089661
# sqft_lot15       0.082447
# yr_built         0.054012
# zipcode          0.053203
# condition        0.036362
# long             0.021626
# id               0.016762
# Name: price, dtype: float64

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
sns.boxplot(x=df['bedrooms']) # outlier az oldugu icin datadan cikarabiliriz
# Out:
# <Axes: xlabel='bedrooms'>

# %%
sns.boxplot(x=df['bathrooms'])
# Out:
# <Axes: xlabel='bathrooms'>

# %%
sns.boxplot(x=df['sqft_living']) # cok fazla oldugu icin outlierlarin hepsini cikaramayiz
# Out:
# <Axes: xlabel='sqft_living'>

# %%
sns.kdeplot(x=df['bedrooms'])
# Out:
# <Axes: xlabel='bedrooms', ylabel='Density'>

# %%
# data az gelirse logaritma alabiliriz
sns.histplot(x=np.log(df['bedrooms']))
# Out:
# <Axes: xlabel='bedrooms', ylabel='Count'>

# %% [markdown]
# ## <font color='purple'> Outlier Removal

# %% [markdown]
# <img src='https://upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Boxplot_vs_PDF.svg/800px-Boxplot_vs_PDF.svg.png'>

# %%
outliers=df.quantile(q=.97,numeric_only=True) # solunu kesmek icin 0.3 yazmamiz lazim

# %%
# outlier kesme, datanin sagini kestik cunku saga dogru uzama vardi
df=df[(df['price']<outliers['price'])]
df=df[(df['bedrooms']<outliers['bedrooms'])]
df=df[(df['bathrooms']<outliers['bathrooms'])]
df=df[(df['sqft_living']<outliers['sqft_living'])]

# %%
sns.histplot(x=df['bedrooms'],bins=20)
# Out:
# <Axes: xlabel='bedrooms', ylabel='Count'>

# %%
sns.histplot(x=df['sqft_living'],bins=20,kde=True)
# Out:
# <Axes: xlabel='sqft_living', ylabel='Count'>

# %%
sns.boxplot(x=df['bedrooms'])
# Out:
# <Axes: xlabel='bedrooms'>

# %% [markdown]
# ## <font color='purple'> Feature Engineering

# %%
df['zipcode']=df['zipcode'].astype('category')

# %%
# yatak odasi onemli oldugu icin, yatak odasinin onemini daha fazla arttirmak istiyoruz
df['bedrooms']=df['bedrooms']**2

# %%
df['bathrooms']=df['bathrooms']**2

# %%
df['sqft_living']=df['sqft_living']**2

# %%
df['age']=datetime.datetime.now().year-df['yr_built']

# %%
# renovasyon yapilmissa 1, yoksa 0
df['yr_renovated']=np.where(df['yr_renovated']>0,1,0)

# %%
# basement var ise 1, yoksa 0
df['sqft_basement']=np.where(df['sqft_basement']>0,1,0)

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         9     1.0000      1392400
# 1  6414100192  20141209T000000  538000.0         9     5.0625      6604900
# 2  5631500400  20150225T000000  180000.0         4     1.0000       592900
# 3  2487200875  20141209T000000  604000.0        16     9.0000      3841600
# 4  1954400510  20150218T000000  510000.0         9     4.0000      2822400
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated zipcode      lat     long  \
# ...

# %% [markdown]
# ## <font color='purple'> Modelling

# %%
x=df.drop(['id','date','lat','long','price'],axis=1) # axis=1 => sutun silme, axis=0 => satur silme
y=df[['price']]

# %%
#zipcode dummy'e cevirme
x=pd.get_dummies(x,drop_first=True)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %% [markdown]
# ### <font color='purple'> Linear Regression

# %%
lr=LinearRegression()

# %%
lrmodel=lr.fit(x_train,y_train)

# %%
lrtahmin=lrmodel.predict(x_test)

# %%
mean_squared_error(y_test,lrtahmin)**0.5
# Out:
# 87443.19353883811

# %%
r2_score(y_test,lrtahmin)
# Out:
# 0.8314604647135578

# %%
# sonuc Hedef R2>.80 ve RMSE<$100K Mission Accomplished

# %% [markdown]
# ### <font color='purple'> Ridge

# %%
R=Ridge()

# %%
rmodel=R.fit(x_train,y_train)

# %%
rtahmin=R.predict(x_test)

# %%
mean_squared_error(y_test,rtahmin)**0.5
# Out:
# 87654.71387513916

# %%
r2_score(y_test,lrtahmin)
# Out:
# 0.8314604647135578

# %% [markdown]
# ### <font color='purple'> Lasso

# %%
L=Lasso()

# %%
lmodel=L.fit(x_train,y_train)

# %%
ltahmin=lmodel.predict(x_test)

# %%
mean_squared_error(y_test,ltahmin)**0.5
# Out:
# 87446.73861116436

# %%
r2_score(y_test,lrtahmin)
# Out:
# 0.8314604647135578

# %% [markdown]
# ### <font color='purple'> ElasticNet

# %%
E=ElasticNet()

# %%
emodel=E.fit(x_train,y_train)

# %%
etahmin=emodel.predict(x_test)

# %%
mean_squared_error(y_test,etahmin)**0.5
# Out:
# 140753.64453555513

# %%
r2_score(y_test,etahmin)
# Out:
# 0.5633142005431933

# %% [markdown]
# ## <font color='purple'> Feature Importance

# %%
feature_importance=pd.DataFrame({'Feature':x_train.columns,'Coefs':lr.coef_[0]})

# %%
feature_importance=feature_importance.sort_values(by='Coefs',ascending=False)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,15))
plt.barh(feature_importance['Feature'],feature_importance['Coefs'])
plt.gca().invert_yaxis()

# %%
residuals=y_test-lrtahmin

# %%
sns.histplot(residuals,bins=100,kde=True) # normal dist. takip ediyor gibi, ama test yapmamiz lazim => sharpio testi ama sonradan bakicaz
# Out:
# <Axes: ylabel='Count'>

# %%
sns.kdeplot(x=residuals['price'],fill=True)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
#pip install xgboost

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 

warnings.filterwarnings("ignore") 
pd.set_option("display.max_columns",100)

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge, Lasso
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor 
from sklearn.tree import ExtraTreeRegressor
from sklearn. tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

def algo_test(x, y):
    # Modelleri tanımlıyorum
    L = LinearRegression()
    R = Ridge()
    Lass = Lasso()
    E = ElasticNet()
    ETR = ExtraTreeRegressor()
    GBR = GradientBoostingRegressor()
    kn = KNeighborsRegressor()
    dt = DecisionTreeRegressor()
    xgb = XGBRegressor()
    
    algo_names = ['Linear', 'Ridge', 'Lasso', 'ElasticNet', 'Extra Tree', 'Gradient Boosting', 'KNeighbors', 'Decision Tree', 'XGBoost']
    algos = [L, R, Lass, E, ETR, GBR, kn, dt, xgb]
    
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
    
    r_squared = []
    rmse = []
    mae = []
    
    # Sonuçları depolamak için bir DataFrame oluşturuyorum
    result = pd.DataFrame(columns=['R_Squared', 'RMSE', 'MAE'], index=algo_names)
    
    for algo in algos:
        # Modeli eğitip tahmin yapıyorum
        p = algo.fit(x_train, y_train).predict(x_test)
        r_squared.append(r2_score(y_test, p))
        rmse.append(mean_squared_error(y_test, p) ** 0.5)
        mae.append(mean_absolute_error(y_test, p))
    
    # Sonuçları tabloya yerleştiriyorum
    result['R_Squared'] = r_squared
    result['RMSE'] = rmse
    result['MAE'] = mae
    
    # Sonuç tablosunu R_Squared'e göre sıralayıp döndürüyorum
    rtable = result.sort_values('R_Squared', ascending=False)
    return rtable

# %%
algo_test(x,y)
# Out:
#   File "C:\Users\ckili\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Users\ckili\anaconda3\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ckili\anaconda3\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Users\ckili\anaconda3\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                    R_Squared           RMSE            MAE
# XGBoost             0.842439   84547.143342   59470.452421
# Linear              0.831460   87443.193539   62911.770521
# Lasso               0.831447   87446.738611   62907.022363
# ...
